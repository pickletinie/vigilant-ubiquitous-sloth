# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv ("2019_NCAABB.csv")
df
# Out:
#     pac 12   Rk                       Team  Conf  Win  Loss  Total Games  \
# 0      NaN  320             Tennessee Tech   OVC    8    23           31
# 1      NaN   85                 Davidson 4   A10   24    10           34
# 2      NaN   62                   Dayton 5   A10   21    12           33
# 3      NaN  173                   Duquesne   A10   19    13           32
# 4      NaN  260                    Fordham   A10   12    20           32
# 5      NaN  156               George Mason   A10   18    15           33
# 6      NaN  293          George Washington   A10    9    24           33
# 7      NaN  228                   La Salle   A10   10    21           31
# 8      NaN  236              Massachusetts   A10   11    21           32
# 9      NaN  142               Rhode Island   A10   18    15           33
# 10     NaN  203                   Richmond   A10   13    20           33
# 11     NaN  189             Saint Joseph's   A10   14    19           33
# ...

# %%
df.describe()
# Out:
#                Rk         Win        Loss  Total Games       AdjEM  \
# count  353.000000  353.000000  353.000000   353.000000  353.000000
# mean   177.000000   17.118980   15.889518    33.008499    0.000142
# std    102.046558    6.364631    5.064552     1.993580   11.957501
# min      1.000000    3.000000    3.000000    28.000000  -29.420000
# 25%     89.000000   12.000000   13.000000    32.000000   -8.280000
# 50%    177.000000   17.000000   16.000000    33.000000   -1.150000
# 75%    265.000000   21.000000   19.000000    34.000000    7.590000
# max    353.000000   35.000000   29.000000    40.000000   34.220000
#
#              AdjO        AdjD        AdjT        Luck     AdjEM.1        OppO  \
# count  353.000000  353.000000  353.000000  353.000000  353.000000  353.000000
# mean   104.317280  104.315864   67.767705    0.000839   -0.336317  104.209632
# std      6.993838    6.493833    2.673105    0.052513    6.000505    3.102083
# ...

# %%
df.dtypes
# Out:
# pac 12          object
# Rk               int64
# Team            object
# Conf            object
# Win              int64
# Loss             int64
# Total Games      int64
# W:L ratio       object
# AdjEM          float64
# AdjO           float64
# AdjD           float64
# AdjT           float64
# Luck           float64
# AdjEM.1        float64
# OppO           float64
# OppD           float64
# AdjEM.2        float64
# dtype: object

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
display(df)
# Out:
#     pac 12   Rk                       Team  Conf  Win  Loss  Total Games  \
# 0      NaN  320             Tennessee Tech   OVC    8    23           31
# 1      NaN   85                 Davidson 4   A10   24    10           34
# 2      NaN   62                   Dayton 5   A10   21    12           33
# 3      NaN  173                   Duquesne   A10   19    13           32
# 4      NaN  260                    Fordham   A10   12    20           32
# 5      NaN  156               George Mason   A10   18    15           33
# 6      NaN  293          George Washington   A10    9    24           33
# 7      NaN  228                   La Salle   A10   10    21           31
# 8      NaN  236              Massachusetts   A10   11    21           32
# 9      NaN  142               Rhode Island   A10   18    15           33
# 10     NaN  203                   Richmond   A10   13    20           33
# 11     NaN  189             Saint Joseph's   A10   14    19           33
# ...

# %%
df.corr()
# Out:
#                    Rk       Win      Loss  Total Games     AdjEM      AdjO  \
# Rk           1.000000 -0.809054  0.774134    -0.616323 -0.975693 -0.869432
# Win         -0.809054  1.000000 -0.964569     0.742142  0.831508  0.759815
# Loss         0.774134 -0.964569  1.000000    -0.539018 -0.790716 -0.728439
# Total Games -0.616323  0.742142 -0.539018     1.000000  0.645884  0.575210
# AdjEM       -0.975693  0.831508 -0.790716     0.645884  1.000000  0.895134
# AdjO        -0.869432  0.759815 -0.728439     0.575210  0.895134  1.000000
# AdjD         0.860405 -0.712809  0.671307    -0.570278 -0.877454 -0.571624
# AdjT         0.029384 -0.007789  0.002380    -0.018820 -0.039739  0.046482
# Luck        -0.060951  0.401613 -0.418115     0.219983  0.067461  0.075460
# AdjEM.1     -0.748870  0.342458 -0.271618     0.403294  0.757774  0.648011
# OppO        -0.719195  0.331263 -0.268876     0.374518  0.730780  0.648033
# ...

# %%
df.to_csv('corrsportball.csv')

# %%
corrMatrix = df.corr()
print (corrMatrix)
# Out:
#                    Rk       Win      Loss  Total Games     AdjEM      AdjO  \
# Rk           1.000000 -0.809054  0.774134    -0.616323 -0.975693 -0.869432
# Win         -0.809054  1.000000 -0.964569     0.742142  0.831508  0.759815
# Loss         0.774134 -0.964569  1.000000    -0.539018 -0.790716 -0.728439
# Total Games -0.616323  0.742142 -0.539018     1.000000  0.645884  0.575210
# AdjEM       -0.975693  0.831508 -0.790716     0.645884  1.000000  0.895134
# AdjO        -0.869432  0.759815 -0.728439     0.575210  0.895134  1.000000
# AdjD         0.860405 -0.712809  0.671307    -0.570278 -0.877454 -0.571624
# AdjT         0.029384 -0.007789  0.002380    -0.018820 -0.039739  0.046482
# Luck        -0.060951  0.401613 -0.418115     0.219983  0.067461  0.075460
# AdjEM.1     -0.748870  0.342458 -0.271618     0.403294  0.757774  0.648011
# OppO        -0.719195  0.331263 -0.268876     0.374518  0.730780  0.648033
# ...

# %%
dfrk = df[df['Rk'] == 'Rank']
dfwn = df[df['Win'] == 'Win']
dfls = df[df['Loss'] == 'Loss']
dftlt = df[df['Total Games'] == 'Total Games']
dfwl = df[df['W:L ratio'] == 'Win ratio']
dfam = df[df['AdjEM'] == 'Adjusted Efficiency Margin']
dfad = df[df['AdjD'] == 'Adjusted Offensive Efficiency']
dfao = df[df['AdjO'] == 'Adjusted Defensive Efficiency']
dflk = df[df['Luck'] == 'Luck']
dfp12 = df[df['pac 12'] == 'PAC-12']
dfp12 = df[df['Conf'] == 'Conf']
# Out:
# C:\Users\sasha\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
import pingouin as pg

# %%
pg.corr(x=df['AdjEM'], y=df['Rk'])
# Out:
#            n         r           CI95%        r2    adj_r2          p-val  \
# pearson  353 -0.975693  [-0.98, -0.97]  0.951976  0.951702  1.717174e-233
#
#               BF10  power
# pearson  8.23e+228    1.0

# %%
corr = df.corr()

kot = corr[corr>=.1]
plt.figure(figsize=(10,8))
sns.heatmap(kot, cmap="Greens")

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

dfd = pd.read_csv ('2019_NCAABBpk12.csv')
dfd
# Out:
#      Rk            Team Conf  Win  Loss  Total Games W:L ratio  AdjEM   AdjO  \
# 0    94         Arizona  P12   17    15           32    53.13%   7.35  105.5
# 1    57  Arizona St. 11  P12   23    11           34    67.65%  11.55  109.7
# 2   241      California  P12    8    23           31    25.81%  -6.84  103.5
# 3    63      Colorado 4  P12   23    13           36    63.89%  10.75  106.8
# 4    28       Oregon 12  P12   25    13           38    65.79%  17.86  109.5
# 5    81      Oregon St.  P12   18    13           31    58.06%   8.33  111.7
# 6   112        Stanford  P12   15    16           31    48.39%   5.47  103.7
# 7   102            UCLA  P12   17    16           33    51.52%   6.34  109.0
# 8    82             USC  P12   16    17           33    48.48%   8.25  109.8
# 9   109            Utah  P12   17    14           31    54.84%   5.85  114.8
# 10   48    Washington 9  P12   27     9           36    75.00%  14.28  107.7
# ...

# %%
dfd.describe()
# Out:
#                Rk        Win       Loss  Total Games      AdjEM        AdjO  \
# count   12.000000  12.000000  12.000000    12.000000  12.000000   12.000000
# mean   102.000000  18.083333  15.083333    33.166667   7.116667  108.175000
# std     62.767971   5.599648   3.941812     2.367712   6.882536    3.275564
# min     28.000000   8.000000   9.000000    31.000000  -6.840000  103.500000
# 25%     61.500000  15.750000  13.000000    31.000000   5.755000  106.175000
# 50%     88.000000  17.000000  14.500000    32.500000   7.800000  108.350000
# 75%    109.750000  23.000000  16.250000    34.500000  10.950000  109.725000
# max    241.000000  27.000000  23.000000    38.000000  17.860000  114.800000
#
#              AdjD       AdjT       Luck    AdjEM.1        OppO        OppD  \
# count   12.000000  12.000000  12.000000  12.000000   12.000000   12.000000
# mean   101.075000  68.091667  -0.008083   4.433333  106.683333  102.250000
# ...

# %%
dfd.corr()
# Out:
#                    Rk       Win      Loss  Total Games     AdjEM      AdjO  \
# Rk           1.000000 -0.915095  0.910121    -0.649016 -0.985589 -0.445303
# Win         -0.915095  1.000000 -0.935268     0.807953  0.944487  0.348554
# Loss         0.910121 -0.935268  1.000000    -0.547093 -0.897631 -0.459592
# Total Games -0.649016  0.807953 -0.547093     1.000000  0.739321  0.059195
# AdjEM       -0.985589  0.944487 -0.897631     0.739321  1.000000  0.407422
# AdjO        -0.445303  0.348554 -0.459592     0.059195  0.407422  1.000000
# AdjD         0.844851 -0.849022  0.740357    -0.775381 -0.880129  0.074933
# AdjT         0.212380 -0.287131  0.257213    -0.250852 -0.296987 -0.168852
# Luck        -0.017794  0.269486 -0.348873     0.056524  0.051796  0.006552
# AdjEM.1     -0.356044  0.366048 -0.401928     0.196567  0.397289  0.078444
# OppO        -0.354601  0.419668 -0.356577     0.398880  0.412651 -0.209424
# ...

# %%
corrMatrix = dfd.corr()
print (corrMatrix)
# Out:
#                    Rk       Win      Loss  Total Games     AdjEM      AdjO  \
# Rk           1.000000 -0.915095  0.910121    -0.649016 -0.985589 -0.445303
# Win         -0.915095  1.000000 -0.935268     0.807953  0.944487  0.348554
# Loss         0.910121 -0.935268  1.000000    -0.547093 -0.897631 -0.459592
# Total Games -0.649016  0.807953 -0.547093     1.000000  0.739321  0.059195
# AdjEM       -0.985589  0.944487 -0.897631     0.739321  1.000000  0.407422
# AdjO        -0.445303  0.348554 -0.459592     0.059195  0.407422  1.000000
# AdjD         0.844851 -0.849022  0.740357    -0.775381 -0.880129  0.074933
# AdjT         0.212380 -0.287131  0.257213    -0.250852 -0.296987 -0.168852
# Luck        -0.017794  0.269486 -0.348873     0.056524  0.051796  0.006552
# AdjEM.1     -0.356044  0.366048 -0.401928     0.196567  0.397289  0.078444
# OppO        -0.354601  0.419668 -0.356577     0.398880  0.412651 -0.209424
# ...

# %%
import seaborn as sns
corr = dfd.corr()

kot = corr[corr>=.1]
plt.figure(figsize=(10,8))
sns.heatmap(kot, cmap="Greens")

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

dfc = pd.read_csv ("COL(1).csv")
dfc
# Out:
#                  City  Cappuccino  Cinema   Wine  Gasoline  Avg Rent   Income
# 0            Lausanne        3.15   12.59   8.40      1.32   1714.00  4266.11
# 1              Zurich        3.28   12.59   8.40      1.31   2378.61  4197.55
# 2              Geneva        2.80   12.94  10.49      1.28   2607.95  3917.72
# 3               Basel        3.50   11.89   7.35      1.25   1649.29  3847.76
# 4               Perth        2.87   11.43  10.08      0.97   2083.14  3358.55
# 5           Nashville        3.84   12.00  13.50      0.65   2257.14  3089.75
# 6            Canberra        2.35   11.42  10.08      0.99   1984.74  3023.91
# 7              Bergen        3.92   12.32  12.32      1.57   1725.37  3002.59
# 8          Luxembourg        2.13    7.25   4.26      1.15   1704.96  2983.69
# 9           Stavanger        4.48   10.65  13.44      1.68   2240.74  2957.77
# 10           Adelaide        2.49   11.42  10.08      0.95   1382.26  2911.69
# ...

# %%
plt.figure(figsize=[10,10])
y = dfc['Avg Rent']
x = dfc['Income']

plt.scatter(x,y,color='#AA1D83')

plt.title('Average Rent vs Income')
plt.ylabel('Avg Rent')
plt.xlabel('Income')
# Out:
# Text(0.5, 0, 'Income')

# %%
cmap = jet(256);
v = rescale(yourValues, 1, 256); 
numValues = length(yourValues)
markerColors = zeros(numValues, 3)
% Now assign marker colors according to the value of the data.
for k = 1 : numValues
    row = round(v(k));
    markerColors(k, :) = cmap(row, :);
end
% Create the scatter plot.
scatter(x, y, [], markerColors);
grid on;
# Out:
#   File "<ipython-input-130-9fbb13fde6c6>", line 6
#     for k = 1 : numValues
#           ^
# SyntaxError: invalid syntax
